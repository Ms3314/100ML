# %%
# univariate analysis

# %%
# we need to gain knowlege from particular columns of a data fame

# %%
# u need to know the category of the particular variable or column

# %%
# we will use the titanic dataset and do the analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/sample_data/tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# har column ko inside out jaana hai mereku but lets start working with catergorical data , we need to visualize the data

# %%
# seaborn , matplotlib , pandas , numpy

# %%
# we will work on categorical data lets go

# %% [markdown]
# # Categorical Data

# %%
df['Survived'].value_counts().plot(kind='bar')
# sns.countplot(df['Survived'])
# Out:
# <Axes: xlabel='Survived'>

# %%
# df['Pclass'].value_counts().plot(kind='bar')
sns.countplot(df , x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# df['Pclass'].value_counts().plot(kind='bar')
sns.countplot(df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# df['Embarked'].value_counts().plot(kind='bar')
sns.countplot(df,x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
stuff = df['Survived'].value_counts().plot(kind='pie' , autopct='%.2f')
#

# %% [markdown]
# # Numerical Data

# %%
import matplotlib.pyplot as plt

# %%
# Histogram
plt.hist(df['Age'], bins=5)
# Out:
# (array([ 32., 168.,  80.,  42.,  10.]),
#  array([ 0.17 , 15.336, 30.502, 45.668, 60.834, 76.   ]),
#  <BarContainer object of 5 artists>)

# %%
# Dist plot

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipython-input-3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# Box plot

# %%
# it is used to give a 5 number summary

# %%
# it is used to remove potentia outliers

# %%
sns.boxplot(df,x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(df,x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
# box plot is usualy used when ur data is noisy to remove outliers and all

# %%
df["Age"].min()
# Out:
# 0.17

# %%
df['Age'].skew()
# Out:
# np.float64(0.4573612871503845)
