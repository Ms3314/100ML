# %%
from bs4 import BeautifulSoup
import requests

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

# %%
soup=BeautifulSoup(webpage,'html')

# %%
for i in range(10):
    url = f"https://www.ambitionbox.com/list-of-companies?page={i}"
    print(url)
    webpage=requests.get(url ,headers=headers).text
    for item in soup.find_all('div',class_="companyCardWrapper"):
        company_name = item.find("h2",class_="companyCardWrapper__companyName").text.strip()
        rating = item.find("div",class_="rating_text").text.strip()
        description_mini = item.find("span",class_="companyCardWrapper__interLinking").text.strip()
        print(company_name )
# Out:
# https://www.ambitionbox.com/list-of-companies?page=0
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Axis Bank
# Concentrix Corporation
# Jio
# Amazon
# iEnergizer
# Reliance Retail
# IBM
# LTIMindtree
# https://www.ambitionbox.com/list-of-companies?page=1
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Axis Bank
# Concentrix Corporation
# Jio
# Amazon
# iEnergizer
# Reliance Retail
# IBM
# LTIMindtree
# https://www.ambitionbox.com/list-of-companies?page=2
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Axis Bank
# Concentrix Corporation
# Jio
# Amazon
# iEnergizer
# Reliance Retail
# IBM
# LTIMindtree
# https://www.ambitionbox.com/list-of-companies?page=3
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# ...

# %%
# for i in range(10):
url = f"https://www.youtube.com"
print(url)
webpage=requests.get(url ,headers=headers).text
# webpage
    # for item in soup.find_all('div',class_="companyCardWrapper"):
    #     company_name = item.find("h2",class_="companyCardWrapper__companyName").text.strip()
    #     rating = item.find("div",class_="rating_text").text.strip()
    #     description_mini = item.find("span",class_="companyCardWrapper__interLinking").text.strip()
    #     print(company_name )
# Out:
# https://www.youtube.com

# %%
# url = "https://medium.com/@hsamiuddin405/cicd-pipeline-for-a-nodejs-express-prisma-backend-an-informal-guide-eac47e1c1cc1"
url = "https://medium.com/@jaelholzman/cant-believe-i-m-just-a-dateline-to-my-friends-09dd7dbd518a"
webpage=requests.get(url ,headers=headers).text
soup=BeautifulSoup(webpage,'html')
article = soup.find("article")
alldivs = article.find("div")
alldivs1 = alldivs.find("div")
heading = alldivs.find("h1")
images = article.find_all("img")
# alldivs1 = alldivs1.find_all("p")
# print(heading.text.strip())
# print(images)
# basically all the 
# for i in alldivs1.find_all("p"):
#     print(i.text.strip())

# print(article.text)
    


# how do i scrap images that are particularly maybe lazy loading and all 

# print(len(alldivs1))
# print(alldivs1)
# item = article.find("div",class_="dw n dx dy dz ea")
# section = article.find("section")
# divneeeded = section.find("div")
# section.text.strip()

# %%
url = "https://www.amazon.in/s?k=nerf+gun"
webpage=requests.get(url ,headers=headers).text
soup=BeautifulSoup(webpage,'html')
# item = soup.find_all("div",role="listitem")
for i in soup.find_all("div",role="listitem"):
    # i.find("div",data-cy="price-recipe")
    symbol = i.find("span",class_="a-price-symbol")
    if type(symbol) != "Nonetype":
        s1 = symbol.text 
        
        
    price = i.find("span",class_="a-price-whole")
    s2 = price.text if type(price) != "Nonetype" else price
    # price ? price.text : price 
    print(i.find("h2").text)
    print(s1 , s2)
    print("----------------------------------")
# Out:
# Nerf Elite 2.0 Eaglepoint RD-8 Toy Blaster, 16 Nerf Darts, Fun Toy for Kids Teens and Adults, Outdoor Play for Boys, Birthday Gift for Kids Ages 8+
# ₹ 2,903
# ----------------------------------
# Nerf Alpha Strike Mantis LR-1 Dart Blaster with Targeting Scope and 5 Official Nerf Elite Foam Darts - Easy Load Prime Fire
# ₹ 689
# ----------------------------------
# Fortnite AR-L Nerf Elite Dart Blaster - Motorized Toy Blaster, 20 Official Nerf Fortnite Elite Darts, Flip Up Sights - for Youth, Teens, Adults
# ₹ 3,399
# ----------------------------------
# Nerf Alpha Strike Big Cat Db-2 Blaster,Double-Barrel Blasting, Fires 2 Darts in A Row,Includes 8 Official Nerf Elite Darts,Multicolor
# ₹ 626
# ----------------------------------
# Nerf Alpha Strike Wolf LR-1 Blaster with Targeting Scope, 12 Nerf Darts, Toys for Kids Teens and Adults, Fun Gift Toy for Boys, Birthday Gift Toy for Kids Ages 8+
# ₹ 661
# ----------------------------------
# ...

# %%
from bs4 import BeautifulSoup
import requests 
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
url = "https://courses.chaicode.com/learn/GenAI-with-Python-2/GenAI-with-python"
webpage=requests.get(url ,headers=headers).text
soup=BeautifulSoup(webpage,'html')
content = soup.find_all(class_="about-product-card")
soup
# item = soup.find_all("div",role="listitem")
# for i in soup.find_all("div",role="listitem"):
#     # i.find("div",data-cy="price-recipe")
#     symbol = i.find("span",class_="a-price-symbol")
#     if type(symbol) != "Nonetype":
#         s1 = symbol.text 
        
        
#     price = i.find("span",class_="a-price-whole")
#     s2 = price.text if type(price) != "Nonetype" else price
#     # price ? price.text : price 
#     print(i.find("h2").text)
#     print(s1 , s2)
#     print("----------------------------------")
# Out:
# <!DOCTYPE html>
# ...
